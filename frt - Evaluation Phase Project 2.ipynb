# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# So the provided link of avocado data set is in excel zip file so we have to extract data from zip file to csv file

# %%
import zipfile

# %%
with zipfile.ZipFile(r'C:\Users\jack9\Downloads\avocado.csv.zip') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# we have extracted the data from zipfile to csv file successfully

# %%
df = pd.read_csv('avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# so the avocado dataset has 18249 no of Rows and 14 no of columns

# %%
print(df.isnull().sum())
sns.heatmap(df.isnull())
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64
# <Axes: >

# %% [markdown]
# we have no null values present in the dataframe

# %%
for i in df:
    print(df[i].value_counts())
    print('\n')
# Out:
# 0     432
# 7     432
# 1     432
# 11    432
# 9     432
# 8     432
# 10    432
# 6     432
# 5     432
# 4     432
# 3     432
# 2     432
# 41    324
# 34    324
# 35    324
# 36    324
# 37    324
# 38    324
# 39    324
# 40    324
# 47    324
# 42    324
# 43    324
# 44    324
# 45    324
# 46    324
# 32    324
# 48    324
# 49    324
# 50    324
# 33    324
# 26    324
# 31    324
# 30    324
# 12    324
# 13    324
# 14    324
# 15    324
# 16    324
# 17    324
# 18    324
# 19    324
# 20    324
# 21    324
# 22    324
# 23    324
# 24    324
# 25    324
# 27    324
# 28    324
# 29    324
# 51    322
# 52    107
# Name: Unnamed: 0, dtype: int64
#
#
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64
#
#
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# ...

# %% [markdown]
# here we can check value count from each column

# %%
df.shape
# Out:
# (18249, 14)

# %%
print(df.nunique())
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# no of unique values in each column appeared

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# here we can check No of Rows and columns, if null values present or no, memory usage

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [raw]
# Converting datatype of datecolumn from object to datetime

# %%
df['Date'] = pd.to_datetime(df.Date, format = '%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [raw]
# Setting date column as dataframe index

# %%
df.set_index('Date',inplace = True)

# %%
df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# here we can observe that in some columns mean and median are almost close to each other and in some column mean is greater than median which is reason for right skewed distribution and in some columns median is greater than mean in that can we can expect left skewed distribution

# %% [markdown]
# looking at 3rd IQR and max values in some columns we can say that outliers present in some columns

# %% [markdown]
# #### Univariate Analysis

# %%
plt.figure(figsize = (5,3))
sns.histplot(df['AveragePrice'])
plt.title('Average Price')
plt.show()

# %% [markdown]
# in this histplot we can see the average price lies between 1 to 2

# %%
plt.figure(figsize = (5,3))
df['Total Volume'].plot(kind='hist', bins=10)
plt.xlabel('Total Volume')
plt.title('Distribution of Total Volume')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x=df['type'])
plt.title('Distribution of Avocado Types')
plt.show()

# %% [markdown]
# there are two types of avocados in dataset conventional and organic and count of both avocados are almost same but conventional avocado is lil hogher

# %%
plt.figure(figsize = (5,3))
sns.countplot(x=df['year'])
plt.title('Avocado sale year by year')
plt.show()

# %% [markdown]
# the sale of avocados in 2015, 2016 and 2017 are almost the same but in 2018 we can see that sale has been not so good it has dropped to around 70% as we can compare to previous years

# %%
plt.figure(figsize = (10,5))
sns.countplot(x=df['region'])
plt.title('avocado sold in different region')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# almost in all the regions avocados are sold in same numbers

# %% [markdown]
# #### Bivariate analysis

# %%
plt.scatter(df['Total Volume'], df['AveragePrice'])
plt.xlabel('Total Volume')
plt.ylabel('Average Price')
plt.title('Average Price and Total Volume')
plt.show()

# %% [markdown]
# as the total volume increases the average price slightly decreases

# %%
sns.scatterplot(data=df,x='AveragePrice', y='year')
plt.xlabel('Average Price')
plt.ylabel('year')
plt.title('Average Price and Total Volume')
plt.show()

# %% [markdown]
# over the year there are fluctuate in average price

# %%
plt.scatter(df['Total Volume'],df['type'])
plt.xlabel('Total Volume')
plt.ylabel('Average Price')
plt.title('Average Price and Total Volume')
plt.show()

# %% [markdown]
# here we can see that conventional type have higher sold volume than organic

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.scatterplot(x='Total Volume', y='AveragePrice', hue='type', data=df)
plt.xlabel('Total Volume')
plt.ylabel('Average Price')
plt.title('Average Price and Total Volume with Type')
plt.show()

# %%
sns.scatterplot(x='Total Volume', y='AveragePrice', hue='year', data=df)
plt.xlabel('Total Volume')
plt.ylabel('Average Price')
plt.title('Average Price and Total Volume with Year')
plt.show()

# %%
plt.figure(figsize = (5,10))
sns.scatterplot(x='AveragePrice', y='region', hue='type', data=df)
plt.xlabel('Total Volume')
plt.ylabel('type')
plt.title('Average Price and Total Volume with Type')
plt.show()

# %% [markdown]
# ### Encoding

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
df['type'] = le.fit_transform(df['type'])
df['year'] = le.fit_transform(df['year'])
df['region'] = le.fit_transform(df['region'])

# %% [markdown]
# so we have converted the categorical data to the numarical data

# %%
for col in df:
    plt.figure(figsize = (3,3))
    sns.distplot(df[col],color = 'green')
    plt.show()

# %%
plt.figure(figsize=(12,20))
plot = 1
for col in df:
    if plot<=20:
        plt.subplot(6,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col)
    plot+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
df1 = df[['AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]
z=np.abs(zscore(df1))
z
# Out:
#             AveragePrice  Total Volume      4046      4225      4770  \
# Date
# 2015-12-27      0.188689      0.227716  0.230816  0.199902  0.212091
# 2015-12-20      0.139020      0.230427  0.231103  0.208054  0.211997
# 2015-12-13      1.182069      0.212085  0.231007  0.154478  0.211325
# 2015-12-06      0.809551      0.223444  0.230741  0.185350  0.211864
# 2015-11-29      0.312861      0.231538  0.230891  0.208719  0.211834
# ...                  ...           ...       ...       ...       ...
# 2018-02-04      0.556347      0.241373  0.230017  0.243857  0.212540
# 2018-01-28      0.755023      0.242296  0.230693  0.242277  0.212540
# 2018-01-21      1.152375      0.242331  0.230693  0.243090  0.205766
# 2018-01-14      1.301382      0.241625  0.230428  0.242651  0.205774
# 2018-01-07      0.531512      0.241253  0.229347  0.243170  0.210450
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags
# Date
# 2015-12-27    0.234170    0.232647    0.222352      0.17558
# ...

# %%
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (17651, 13)

# %%
print('Loss of Data in percentage',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Loss of Data in percentage 3.276891884486821

# %%
df.skew()
# Out:
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
df['Total Volume'] = np.cbrt(df['Total Volume'])
df['4046'] = np.cbrt(df['4046'])
df['4225'] = np.cbrt(df['4225'])
df['4770'] = np.cbrt(df['4770'])
df['Total Bags'] = np.cbrt(df['Total Bags'])
df['Small Bags'] = np.cbrt(df['Small Bags'])
df['Large Bags'] = np.cbrt(df['Large Bags'])
df['XLarge Bags'] = np.cbrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# Unnamed: 0      0.108334
# AveragePrice    0.580303
# Total Volume    2.236143
# 4046            2.277861
# 4225            2.130378
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %%
df['Total Volume'] = np.sqrt(df['Total Volume'])
df['4046'] = np.sqrt(df['4046'])
df['4225'] = np.sqrt(df['4225'])
df['4770'] = np.sqrt(df['4770'])
df['Total Bags'] = np.sqrt(df['Total Bags'])
df['Small Bags'] = np.sqrt(df['Small Bags'])
df['Large Bags'] = np.sqrt(df['Large Bags'])
df['XLarge Bags'] = np.sqrt(df['XLarge Bags'])

# %%
df.skew()
# Out:
# Unnamed: 0      0.108334
# AveragePrice    0.580303
# Total Volume    0.950027
# 4046            0.850203
# 4225            0.717992
# 4770            0.605972
# Total Bags      0.890696
# Small Bags      0.690221
# Large Bags      0.316832
# XLarge Bags     1.377477
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot= True)
# Out:
# <Axes: >

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

# %%
features = df.drop(columns=['type'])  
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
vif_data = pd.DataFrame()
vif_data["Feature"] = features.columns
vif_data["VIF"] = [variance_inflation_factor(scaled_features, i) for i in range(scaled_features.shape[1])]
vif_data
# Out:
#          Feature         VIF
# 0     Unnamed: 0    1.063988
# 1   AveragePrice    1.752963
# 2   Total Volume  116.957681
# 3           4046   13.371225
# 4           4225   23.342607
# 5           4770    4.301264
# 6     Total Bags   58.943136
# 7     Small Bags   27.026750
# 8     Large Bags    4.580881
# 9    XLarge Bags    2.303227
# 10          year    1.440999
# 11        region    1.123139

# %% [markdown]
# spitting the data

# %%
x = df.drop('type',axis=1)
y = df['type']

# %%
x.shape
# Out:
# (18249, 12)

# %%
y.shape
# Out:
# (18249,)

# %%
sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#        Unnamed: 0  AveragePrice  Total Volume      4046      4225      4770  \
# 0       -1.565327     -0.188689     -0.275399 -0.715829  0.173710 -0.310250
# 1       -1.500730     -0.139020     -0.334355 -0.795270  0.094757 -0.283521
# 2       -1.436133     -1.182069     -0.031861 -0.765596  0.471429 -0.161360
# 3       -1.371536     -0.809551     -0.195601 -0.698883  0.289024 -0.251967
# 4       -1.306939     -0.312861     -0.360978 -0.734126  0.087699 -0.245601
# ...           ...           ...           ...       ...       ...       ...
# 18244   -1.113149      0.556347     -0.726346 -0.577981 -0.913422 -1.134031
# 18245   -1.048552      0.755023     -0.788107 -0.688860 -0.720791 -1.134031
# 18246   -0.983955      1.152375     -0.790683 -0.688824 -0.803977  0.161298
# 18247   -0.919358      1.301382     -0.742176 -0.639200 -0.756223  0.161022
# 18248   -0.854761      0.531512     -0.719032 -0.501515 -0.813629 -0.069292
#
# ...

# %%
y.value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %% [markdown]
# ## Building Model

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=0)

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
predlog = log.predict(x_test)
print(accuracy_score(y_test,predlog))
# Out:
# 0.96

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
predrfc = rfc.predict(x_test)
print('The accuracy for RandomForestClassifier is = ',accuracy_score(y_test, predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# The accuracy for RandomForestClassifier is =  0.9963470319634703
# [[2720    6]
#  [  14 2735]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2726
#            1       1.00      0.99      1.00      2749
#
#     accuracy                           1.00      5475
#    macro avg       1.00      1.00      1.00      5475
# weighted avg       1.00      1.00      1.00      5475

# %%
abc = AdaBoostClassifier()
abc.fit(x_train,y_train)
predabc = abc.predict(x_test)
print('The accuracy for AdaBoostClassifier is = ',accuracy_score(y_test,predabc))
print(confusion_matrix(y_test,predabc))
print(classification_report(y_test,predabc))
# Out:
# The accuracy for AdaBoostClassifier is =  0.9923287671232877
# [[2711   15]
#  [  27 2722]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2726
#            1       0.99      0.99      0.99      2749
#
#     accuracy                           0.99      5475
#    macro avg       0.99      0.99      0.99      5475
# weighted avg       0.99      0.99      0.99      5475

# %%
bc = BaggingClassifier()
bc.fit(x_train,y_train)
predbc = bc.predict(x_test)
print('The accuracy for BaggingClassifier is = ',accuracy_score(y_test,predbc))
print(confusion_matrix(y_test,predbc))
print(classification_report(y_test,predbc))
# Out:
# The accuracy for BaggingClassifier is =  0.9932420091324201
# [[2715   11]
#  [  26 2723]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2726
#            1       1.00      0.99      0.99      2749
#
#     accuracy                           0.99      5475
#    macro avg       0.99      0.99      0.99      5475
# weighted avg       0.99      0.99      0.99      5475

# %%
etc = ExtraTreesClassifier()
etc.fit(x_train,y_train)
predetc = etc.predict(x_test)
print('The accuracy for ExtraTreesClassifier is = ',accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# The accuracy for ExtraTreesClassifier is =  0.9981735159817352
# [[2722    4]
#  [   6 2743]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2726
#            1       1.00      1.00      1.00      2749
#
#     accuracy                           1.00      5475
#    macro avg       1.00      1.00      1.00      5475
# weighted avg       1.00      1.00      1.00      5475

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
predtc = dtc.predict(x_test)
print('The accuracy for DecisionTreeClassifier is = ',accuracy_score(y_test,predtc))
print(confusion_matrix(y_test,predtc))
print(classification_report(y_test,predtc))
# Out:
# The accuracy for DecisionTreeClassifier is =  0.9910502283105023
# [[2699   27]
#  [  22 2727]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2726
#            1       0.99      0.99      0.99      2749
#
#     accuracy                           0.99      5475
#    macro avg       0.99      0.99      0.99      5475
# weighted avg       0.99      0.99      0.99      5475

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn = knn.predict(x_test)
print('The accuracy of KNeighborsClassifier is = ',accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# The accuracy of KNeighborsClassifier is =  0.9976255707762557
# [[2720    6]
#  [   7 2742]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2726
#            1       1.00      1.00      1.00      2749
#
#     accuracy                           1.00      5475
#    macro avg       1.00      1.00      1.00      5475
# weighted avg       1.00      1.00      1.00      5475

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print('The accuracy of SVC is = ',accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# The accuracy of SVC is =  0.9903196347031964
# [[2696   30]
#  [  23 2726]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2726
#            1       0.99      0.99      0.99      2749
#
#     accuracy                           0.99      5475
#    macro avg       0.99      0.99      0.99      5475
# weighted avg       0.99      0.99      0.99      5475

# %% [markdown]
# Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(log,x,y)
print(score)
print(score.mean())
print('difference in accuracy',accuracy_score(y_test,predlog)-score.mean())
# Out:
# [0.96410959 0.94794521 0.96849315 0.94027397 0.94107975]
# 0.9523803331368699
# difference in accuracy 0.007619666863130092

# %%
score = cross_val_score(rfc,x,y)
print(score)
print(score.mean())
print('difference in accuracy',accuracy_score(y_test,predrfc)-score.mean())
# Out:
# [0.99287671 0.9890411  0.99342466 0.99232877 0.9706769 ]
# 0.9876696261313851
# difference in accuracy 0.008677405832085205

# %%
score1 = cross_val_score(abc,x,y)
print(score1)
print(score1.mean())
print('difference in accuracy',accuracy_score(y_test,predabc)-score1.mean())
# Out:
# [0.98520548 0.98575342 0.98958904 0.98410959 0.96738833]
# 0.9824091719630449
# difference in accuracy 0.009919595160242767

# %%
score1 = cross_val_score(abc,x,y)
print(score1)
print(score1.mean())
print('difference in accuracy',accuracy_score(y_test,predabc)-score1.mean())
# Out:
# [0.98520548 0.98575342 0.98958904 0.98410959 0.96738833]
# 0.9824091719630449
# difference in accuracy 0.009919595160242767

# %%
score3 = cross_val_score(dtc,x,y)
print(score3)
print(score3.mean())
print('difference in accuracy',accuracy_score(y_test,predtc)-score3.mean())
# Out:
# [0.9739726  0.97589041 0.9830137  0.97561644 0.96355166]
# 0.9744089617346843
# difference in accuracy 0.016641266575817992

# %%
score4 = cross_val_score(knn,x,y)
print(score4)
print(score4.mean())
print('difference in accuracy',accuracy_score(y_test,predknn)-score4.mean())
# Out:
# [0.98575342 0.98027397 0.96849315 0.97041096 0.95889285]
# 0.9727648708409511
# difference in accuracy 0.024860699935304598

# %%
score5 = cross_val_score(etc,x,y)
print(score5)
print(score5.mean())
print('The difference in accuracy',accuracy_score(y_test,predetc))
# Out:
# [0.99561644 0.98136986 0.99643836 0.9909589  0.96903261]
# 0.9866832346636534
# The difference in accuracy 0.9981735159817352

# %%
score6 = cross_val_score(svc,x,y)
print(score6)
print(score6.mean())
print('The difference in accuracy',accuracy_score(y_test,predsvc))
# Out:
# [0.97835616 0.98273973 0.98575342 0.97945205 0.96135928]
# 0.9775321292754254
# The difference in accuracy 0.9903196347031964

# %% [markdown]
# Extra Tree Classifier is the best model as the accuracy score is high and also least differene between accuracy score and cross validation score

# %% [markdown]
# Hyper parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'criterion' : ['gini','entropy'],
         'random_state' : [10,50,100,1000],
         'max_depth' : [0,10,20],
         'n_jobs' : [-2,-1,1],
         'n_estimators' : [50,100,200,300]}

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),params,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 100, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 100}

# %%
final_model = ExtraTreesClassifier(criterion = 'entropy', max_depth = 10, n_estimators = 200, n_jobs = -2, random_state = 1000)
final_model.fit(x_train,y_train)
pred = final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 98.35616438356163

# %% [markdown]
# ### AUC and ROC CURVE

# %%
from sklearn import metrics
fpr, tpr, thresholds=metrics.roc_curve(y_test, pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr = fpr, tpr = tpr, roc_auc = roc_auc, estimator_name=final_model)
display.plot()

# %% [markdown]
# #### Saving model

# %%
import joblib

# %%
joblib.dump(final_model,'Avocado_prediction.pkl')
# Out:
# ['Avocado_prediction.pkl']

# %%
model = joblib.load('Avocado_prediction.pkl')

# %%
prediction = model.predict(x_test)
prediction
# Out:
# array([1, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
data = pd.DataFrame({'model predicted':prediction,'original':y_test})
data
# Out:
#             model predicted  original
# Date
# 2015-12-06                1         1
# 2015-07-05                0         0
# 2016-03-20                1         1
# 2017-09-10                1         1
# 2018-01-14                1         1
# ...                     ...       ...
# 2017-01-08                1         1
# 2017-03-26                1         1
# 2017-09-17                0         0
# 2015-02-08                1         1
# 2016-12-25                0         0
#
# [5475 rows x 2 columns]
