# %% [markdown]
# # Baseball Case Study

# %%
import numpy as np 
import pandas as pd
 
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'Baseball.csv')

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# we have successfully loaded the baseball dataset to the notebook

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# so we have 30 no of rows and 17 no of columns which consists of 16 feature columns and 1 target column

# %% [markdown]
# cheching for null values

# %%
df.isnull().sum()

plt.figure(figsize = (8,5))
sns.heatmap(df.isnull())           
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There are no null values present in the dataset

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# here we can check on data types of each columns we have int values and float values

# %% [raw]
# checking for repeated values in each columns

# %%
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# here we can check mean, median, std deviation, min, max, IQR range values
#
# so in this baseball dataset we have mean and median values close to each other in each columns

# %% [markdown]
# #### Univariate Analysis

# %%
for col in df:
    plt.figure(figsize = (3,3))
    plt.hist(df[col])
    sns.distplot(df[col])
    plt.show()

# %%
for col in df:
    plt.figure(figsize = (3,3))
    sns.distplot(df[col],color = 'green')
    plt.show()

# %% [markdown]
# #### Bivariate Analysis

# %%
plt.figure(figsize=(5,4))
plt.scatter(df['R'], df['W'])
plt.xlabel('Runs scored(R)')
plt.ylabel('Number of wins(W)')
plt.title('Wins and Runs Scored')
plt.show()

# %% [markdown]
# here we can see that more the rusn are scored higher the winning chance is

# %%
plt.figure(figsize = (5,4))
plt.scatter(df['ERA'], df['W'])
plt.xlabel('Earned Run Average')
plt.ylabel('Wins')
plt.title('Earned Run Average and Wins')
plt.show()

# %% [markdown]
# here we can see that higher the Earned Run Averages higher the winning chances

# %%
plt.figure(figsize=(5,4))
plt.scatter(df['R'],df['ERA'])
plt.xlabel('R')
plt.ylabel('ERA')
plt.title('Runs scored and Earned Run Average')
plt.show()

# %% [markdown]
# Teams which score high runs have higher Earned Run Average

# %%
plt.scatter(df['H'], df['R'], color='red')
plt.xlabel('Number of Hits (H)')
plt.ylabel('Runs Scored (R)')
plt.title('Hits vs. Runs Scored')
plt.show()

# %% [markdown]
# Teams which hits balls more have higher run scores

# %% [markdown]
# #### Multivariate Analysis

# %%
selected_variables = ['W', 'R', 'ERA', 'H']
sns.pairplot(df[selected_variables], diag_kind='kde', markers='o', palette='coolwarm')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Checking for outliers

# %%
plt.figure(figsize=(12,20))
plot = 1
for col in df:
    if plot<=20:
        plt.subplot(6,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col)
    plot+=1
plt.show()

# %% [markdown]
# So there are few outliers present in some columns  and we need to remove outliers with help of zscore method

# %%
from scipy.stats import zscore

# %%
df1 = df[['R','ERA','SHO','SV','E']]
z=np.abs(zscore(df1))
z
# Out:
#            R       ERA       SHO        SV         E
# 0   0.619078  0.506955  0.814629  1.671607  0.461470
# 1   0.134432  0.254598  0.172800  0.249879  0.607197
# 2   0.332906  0.641347  0.320914  0.654856  1.117242
# 3   1.146419  0.053010  0.567771  0.784104  0.485758
# 4   0.013270  1.531318  0.172800  1.042600  0.607197
# 5   3.509647  0.350165  0.320914  1.171848  0.461470
# 6   1.311430  0.165003  1.802057  0.637623  0.097152
# 7   0.428681  0.209800  0.320914  0.008617  1.262970
# 8   0.765626  0.484557  0.172800  2.188598  0.048576
# 9   1.034489  0.792164  0.320914  0.396360  0.194303
# 10  1.086415  0.635374  0.567771  0.249879  1.797303
# 11  0.705622  0.865333  0.419657  0.525608  0.680061
# 12  0.471376  0.036584  0.172800  0.379127  0.097152
# 13  0.557920  0.456185  0.172800  0.249879  0.024288
# 14  0.099814  0.411388  0.913371  1.947335  2.307348
# 15  0.713699  2.276445  0.913371  2.447094  0.121439
# 16  0.151740  1.671683  0.419657  1.413111  2.015894
# ...

# %% [markdown]
# Now lets check are there any value which are > zscore value(3)

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29, 17)

# %% [markdown]
# So we have removed outliers

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['R'] = np.sqrt(df['R'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# skewnesss has removed from the Run scored(R) column

# %%
df.corr()
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# from the heatmap we can clearly see that there is strong corelation between RA with ERA and ER

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def pca(df, n_components):
    features = df.drop(columns=['W'])  
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(features)
    
    pca = PCA(n_components=n_components)
    principal_components = pca.fit_transform(scaled_features)
    pca_data = pd.DataFrame(data=principal_components, columns=[f'PC{i}' for i in range(1, n_components + 1)])
    
    return pca_data

n_components = 2 
pca_results = pca(df, n_components)
print(pca_results)
# Out:
#          PC1       PC2
# 0   0.865100  2.139874
# 1   0.130588 -0.854986
# 2  -1.311890  1.163237
# 3   0.768493 -1.394451
# 4   3.321687  1.693377
# 5  -0.929727  4.003195
# 6  -0.293454  0.736262
# 7  -0.593588 -1.950347
# 8  -1.322823 -0.729122
# 9   2.058977  2.078289
# 10  1.035715  1.006716
# 11 -2.033966  0.755470
# 12 -1.010125 -2.697771
# 13 -0.088362 -0.734538
# 14  1.838727  0.850924
# 15 -3.956857  0.256584
# 16 -1.543352  1.707708
# 17 -3.546392  0.358061
# 18  1.645715 -1.430557
# 19  1.880566 -0.659262
# 20 -2.844599 -0.066588
# 21 -2.674823 -0.879877
# 22  1.328826 -2.231682
# 23  0.898283 -3.286844
# 24  3.523478 -1.853553
# 25 -4.066338 -0.751491
# 26 -0.439880  2.000200
# 27  1.593162  2.457214
# 28  0.801384 -2.308132
# 29  4.965475  0.622089

# %% [markdown]
# spitting the data

# %%
x = df.drop('W',axis=1)
y = df['W']

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.643360  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.157187 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.320974 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.176953  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.034123  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.365868 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.321867  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.453505 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.772397 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.052647  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.103344 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.729182 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=.30, random_state=42)


lr = LinearRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
print(mean_squared_error(y_test,predlr))
print(mean_absolute_error(y_test,predlr))
print(r2_score(y_test,predlr))
# Out:
# 27.019239285249576
# 4.160783406687961
# 0.7993620845154734

# %%
la = Lasso()
la.fit(x_train,y_train)
predla = la.predict(x_test)
print(mean_squared_error(y_test,predla))
print(mean_absolute_error(y_test,predla))
print(r2_score(y_test,predla))
# Out:
# 23.439226872844063
# 4.062209651547146
# 0.825946335102643

# %%
rg = Ridge()
rg.fit(x_train,y_train)
predrg = rg.predict(x_test)
print(mean_squared_error(y_test,predrg))
print(mean_absolute_error(y_test,predrg))
print(r2_score(y_test,predrg))
# Out:
# 22.779966131992353
# 3.6391854399131613
# 0.8308418356535221

# %%
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr = rfr.predict(x_test)
print(mean_squared_error(y_test,predrfr))
print(mean_absolute_error(y_test,predrfr))
print(r2_score(y_test,predrfr))
# Out:
# 41.162599999999976
# 5.355555555555554
# 0.6943371287128715

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
predetr = etr.predict(x_test)
print(mean_squared_error(y_test,predetr))
print(mean_absolute_error(y_test,predetr))
print(r2_score(y_test,predetr))
# Out:
# 33.189155555555544
# 5.108888888888888
# 0.7535458745874588

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
predtr = dtr.predict(x_test)
print(mean_squared_error(y_test,predtr))
print(mean_absolute_error(y_test,predtr))
print(r2_score(y_test,predtr))
# Out:
# 87.55555555555556
# 7.555555555555555
# 0.34983498349834985

# %%
knr = KNeighborsRegressor()
knr.fit(x_train,y_train)
predknr = knr.predict(x_test)
print(mean_squared_error(y_test,predknr))
print(mean_absolute_error(y_test,predknr))
print(r2_score(y_test,predknr))
# Out:
# 49.94222222222219
# 5.71111111111111
# 0.6291419141914194

# %% [markdown]
# Lets check for Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score1 = cross_val_score(lr,x,y)
print(score1)
print(score1.mean())
print('difference in r2_score and cvs',r2_score(y_test,predlr)-score1.mean())
# Out:
# [ 0.78031151 -2.13448082  0.44823195  0.74205242  0.53381371]
# 0.07398575228148074
# difference in r2_score and cvs 0.7253763322339927

# %%
score2 = cross_val_score(la,x,y)
print(score2)
print(score2.mean())
print('difference in r2_score and cvs',r2_score(y_test,predla)-score2.mean())
# Out:
# [ 0.7848152  -0.42643905  0.66696357  0.69227716  0.91308522]
# 0.5261404212378064
# difference in r2_score and cvs 0.2998059138648367

# %%
score3 = cross_val_score(rg,x,y)
print(score3)
print(score3.mean())
print('difference in r2_score and cvs',r2_score(y_test,predrg)-score3.mean())
# Out:
# [ 0.71854855 -1.03764674  0.59559511  0.769415    0.88941298]
# 0.38706498212242524
# difference in r2_score and cvs 0.44377685353109686

# %%
score4 = cross_val_score(rfr,x,y)
print(score4)
print(score4.mean())
print('difference in r2_score and cvs',r2_score(y_test,predrfr)-score4.mean())
# Out:
# [ 0.22248206 -5.16493244  0.20186302  0.32206179  0.77316059]
# -0.7290729954784737
# difference in r2_score and cvs 1.4234101241913453

# %%
score5 = cross_val_score(etr,x,y)
print(score5)
print(score5.mean())
print('difference in r2_score and cvs',r2_score(y_test,predetr)-score5.mean())
# Out:
# [-0.07844671 -4.43306756  0.4580941   0.3124179   0.79684728]
# -0.588830999860274
# difference in r2_score and cvs 1.3423768744477327

# %%
score6 = cross_val_score(dtr,x,y)
print(score6)
print(score6.mean())
print('difference in r2_score and cvs',r2_score(y_test,predtr)-score6.mean())
# Out:
# [-1.69094139 -9.8778626  -0.39146992 -0.16043956  0.49585799]
# -2.324971093870257
# difference in r2_score and cvs 2.674806077368607

# %%
score7 = cross_val_score(knr,x,y)
print(score7)
print(score7.mean())
print('difference in r2_score and cvs',r2_score(y_test,predknr)-score7.mean())
# Out:
# [ 0.3164476  -2.36687023  0.34941356  0.34337206  0.56615385]
# -0.15829663349342904
# difference in r2_score and cvs 0.7874385476848484

# %% [markdown]
# So the lasso is best model as it is getting least difference in r2_score and cvs and getting best re_score

# %% [markdown]
# Hyper parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
LassoRegression = Lasso()
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]}
lrGCV = GridSearchCV(LassoRegression, params, scoring='neg_mean_squared_error', cv=5)
lrGCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')

# %%
best_params = lrGCV.best_params_['alpha']

# %%
final_model_lasso = Lasso(best_params)
final_model_lasso.fit(x_train,y_train)
pred = final_model_lasso.predict(x_test)
r2 = r2_score(y_test, pred)
print(r2*100)
# Out:
# 82.5946335102643

# %% [markdown]
# ### Saving model

# %%
import joblib

# %%
joblib.dump(final_model_lasso,'Baseball_win_prediction.pkl')
# Out:
# ['Baseball_win_prediction.pkl']

# %%
model = joblib.load('Baseball_win_prediction.pkl')
model
# Out:
# Lasso(alpha=1)

# %%
prediction = model.predict(x_test)
prediction
# Out:
# array([83.13090658, 99.14131697, 69.96162577, 89.85100406, 89.88506037,
#        80.06996897, 76.40709999, 66.16729938, 81.06975317])

# %%
data = pd.DataFrame({'model predicted':prediction,'original':y_test})
data
# Out:
#     model predicted  original
# 27        83.130907        79
# 15        99.141317       100
# 23        69.961626        67
# 17        89.851004        97
# 8         89.885060        80
# 9         80.069969        78
# 28        76.407100        74
# 24        66.167299        63
# 12        81.069753        85

# %%
df.head()
# Out:
#     W          R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0  95  26.907248  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1  83  26.381812  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2  81  25.865034  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3  76  24.939928  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4  74  26.248809  5605  1515  289  49  151  455  1259   83  803  746  4.64
#
#    CG  SHO  SV    E
# 0   2    8  56   88
# 1   2   12  45   86
# 2  11   10  38   79
# 3   7    9  37  101
# 4   7   12  35   86
